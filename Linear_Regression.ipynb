# %% [markdown]
# <a href="https://colab.research.google.com/github/rieckace/AI-Agent-Sample-/blob/master-branch/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a = pd.read_csv("/content/SOCR-HeightWeight.csv")

# %%
display(a.head())
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Index'].plot(kind='hist', bins=20, title='Index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Height(Inches)'].plot(kind='hist', bins=20, title='Height(Inches)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Weight(Pounds)'].plot(kind='hist', bins=20, title='Weight(Pounds)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
# ...

# %%
a.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
x = a[["Height(Inches)"]]
y = a["Weight(Pounds)"]

# %%
x.head()
# Out:
#    Height(Inches)
# 0        65.78331
# 1        71.51521
# 2        69.39874
# 3        68.21660
# 4        67.78781

# %%
y.head()
# Out:
# 0    112.9925
# 1    136.4873
# 2    153.0269
# 3    142.3354
# 4    144.2971
# Name: Weight(Pounds), dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin = LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lin.predict(x_test)

# %%
y_pred
# Out:
# array([136.64480344, 127.72267402, 127.85236052, ..., 139.1599701 ,
#        123.21915554, 137.24383743])

# %%
y_pred.shape
# Out:
# (5000,)

# %%
y_test.shape
# Out:
# (5000,)

# %%
y_test
# Out:
# 14694    133.8311
# 22211    126.6700
# 19253    126.9731
# 24724    145.0337
# 22887    113.9887
#            ...
# 24645    131.8460
# 12952    123.6610
# 6864     147.5959
# 13606    130.6229
# 8203     142.6142
# Name: Weight(Pounds), Length: 5000, dtype: float64

# %%
from sklearn.metrics import r2_score,mean_absolute_error
r2_score(y_test, y_pred)
# Out:
# 0.26145766094365497

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 7.918916609743709
